# %%
#importing modules

import numpy as np
import pandas as pd 
import os
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, IntegerType, StringType

from pyspark.sql.functions import round
from pyspark.ml.feature import StringIndexer
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.classification import DecisionTreeClassifier
from pyspark.ml.classification import LogisticRegression
from pyspark.ml.evaluation import MulticlassClassificationEvaluator, BinaryClassificationEvaluator

# %%
url = "https://raw.githubusercontent.com/Cyndie-Matinou/fuel_consumption/master/cars_one.csv"
from pyspark import SparkFiles
spark.sparkContext.addFile(url)

df = spark.read.csv("file://"+SparkFiles.get("cars_one.csv"), header=True, inferSchema= True)

# %%
#performing some data cleansing
cols = ("car","_c9","_c10","_c11","_c12","_c13")

df=df.drop(*cols) 
#.printSchema()
df.show()
# Out:
# +----+---------+------------+----------+------+------------+-----+------+
# | mpg|cylinders|displacement|horsepower|weight|acceleration|model|origin|
# +----+---------+------------+----------+------+------------+-----+------+
# |18.0|        8|         307|       130|  3504|        12.0|   70|     1|
# |15.0|        8|         350|       165|  3693|        11.5|   70|     1|
# |18.0|        8|         318|       150|  3436|        11.0|   70|     1|
# |16.0|        8|         304|       150|  3433|        12.0|   70|     1|
# |17.0|        8|         302|       140|  3449|        10.5|   70|     1|
# |15.0|        8|         429|       198|  4341|        10.0|   70|     1|
# |14.0|        8|         454|       220|  4354|         9.0|   70|     1|
# |14.0|        8|         440|       215|  4312|         8.5|   70|     1|
# |14.0|        8|         455|       225|  4425|        10.0|   70|     1|
# |15.0|        8|         390|       190|  3850|         8.5|   70|     1|
# |15.0|        8|         383|       170|  3563|        10.0|   70|     1|
# |14.0|        8|         340|       160|  3609|         8.0|   70|     1|
# |15.0|        8|         400|       150|  3761|         9.5|   70|     1|
# |14.0|        8|         455|       225|  3086|        10.0|   70|     1|
# |24.0|        4|         113|        95|  2372|        15.0|   70|     3|
# |22.0|        6|         198|        95|  2833|        15.5|   70|     1|
# |18.0|        6|         199|        97|  2774|        15.5|   70|     1|
# |21.0|        6|         200|        85|  2587|        16.0|   70|     1|
# |27.0|        4|          97|        88|  2130|        14.5|   70|     3|
# |26.0|        4|          97|        46|  1835|        20.5|   70|     2|
# +----+---------+------------+----------+------+------------+-----+------+
# only showing top 20 rows

# %%
#data cleansing, getting rid of duplicates
df.drop_duplicates()
# Out:
# Out[23]: DataFrame[mpg: double, cylinders: int, displacement: int, horsepower: string, weight: int, acceleration: double, model: int, origin: int]

# %%
df.dropna()
# Out:
# Out[24]: DataFrame[mpg: double, cylinders: int, displacement: int, horsepower: string, weight: int, acceleration: double, model: int, origin: int]

# %%
#visualising the dataframe
display(df)

#let's visualize the distribution of the features of the cars
#i decided to use histograms
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mpg</th><th>cylinders</th><th>displacement</th><th>horsepower</th><th>weight</th><th>acceleration</th><th>model</th><th>origin</th></tr></thead><tbody><tr><td>18.0</td><td>8</td><td>307</td><td>130</td><td>3504</td><td>12.0</td><td>70</td><td>1</td></tr><tr><td>15.0</td><td>8</td><td>350</td><td>165</td><td>3693</td><td>11.5</td><td>70</td><td>1</td></tr><tr><td>18.0</td><td>8</td><td>318</td><td>150</td><td>3436</td><td>11.0</td><td>70</td><td>1</td></tr><tr><td>16.0</td><td>8</td><td>304</td><td>150</td><td>3433</td><td>12.0</td><td>70</td><td>1</td></tr><tr><td>17.0</td><td>8</td><td>302</td><td>140</td><td>3449</td><td>10.5</td><td>70</td><td>1</td></tr><tr><td>15.0</td><td>8</td><td
td><td>4</td><td>98</td><td>?</td><td>2046</td><td>19.0</td><td>71</td><td>1</td></tr><tr><td>19.0</td><td>6</td><td>232</td><td>100</td><td>2634</td><td>13.0</td><td>71</td><td>1</td></tr><tr><td>16.0</td><td>6</td><td>225</td><td>105</td><td>3439</td><td>15.5</td><td>71</td><td>1</td></tr><tr><td>17.0</td><td>6</td><td>250</td><td>100</td><td>3329</td><td>15.5</td><td>71</td><td>1</td></tr><tr><td>19.0</td><td>6</td><td>250</td><td>88</ ...

# %%
#this is where the fun part starts
#I am going to visualize the relationships between the Mileage Per Galon(mpg) of a car and the other features.

#1 I start with cylinders
from pyspark.sql.functions import corr
df.select(corr("mpg", "cylinders")).show()
# Out:
# +--------------------+
# |corr(mpg, cylinders)|
# +--------------------+
# | -0.8667867876973869|
# +--------------------+

# %%
#2 mpg of a car and displacement
df.select(corr("mpg", "displacement")).show()
# Out:
# +-----------------------+
# |corr(mpg, displacement)|
# +-----------------------+
# |    -0.8851367055258322|
# +-----------------------+

# %%
#3 mpg and horsepower
df.select(corr("mpg", "horsepower")).show()
# Out:
# +---------------------+
# |corr(mpg, horsepower)|
# +---------------------+
# |  -0.8154545895904027|
# +---------------------+

# %%
#4 mpg and weight
df.select(corr("mpg", "weight")).show()
# Out:
# +-------------------+
# |  corr(mpg, weight)|
# +-------------------+
# |-0.9042371479265466|
# +-------------------+

# %%
#5 mpg and acceleration
df.select(corr("mpg","acceleration")).show()
# Out:
# +-----------------------+
# |corr(mpg, acceleration)|
# +-----------------------+
# |     0.5318790511742024|
# +-----------------------+

# %%
#6 mpg and model
df.select(corr("mpg","model")).show()
# Out:
# +-------------------+
# |   corr(mpg, model)|
# +-------------------+
# |0.18179123717662585|
# +-------------------+

# %%
#7 mpg and origin
df.select(corr("mpg","origin")).show()
# Out:
# +-----------------+
# |corr(mpg, origin)|
# +-----------------+
# |0.657652196695826|
# +-----------------+

# %%
#train/test split
traindf, testdf = df.randomSplit([.8, .2], seed=56)

# %%
#Split the dataset into train and test set 
(trainRepartitiondf, testRepartitiondf) = (df
                                           .repartition(24)
                                           .randomSplit([.8, .2], seed=56))

print(trainRepartitiondf.count())
# Out:
# 157

# %%
#I am starting with mpg and acceleration. I want to predict the mpg based on acceleration
display(df.select("mpg", "acceleration").summary())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>mpg</th><th>acceleration</th></tr></thead><tbody><tr><td>count</td><td>198</td><td>198</td></tr><tr><td>mean</td><td>19.71969696969697</td><td>15.005555555555555</td></tr><tr><td>stddev</td><td>5.814253963002064</td><td>2.8723819586167947</td></tr><tr><td>min</td><td>9.0</td><td>8.0</td></tr><tr><td>25%</td><td>15.0</td><td>13.0</td></tr><tr><td>50%</td><td>19.0</td><td>15.0</td></tr><tr><td>75%</td><td>24.5</td><td>16.9</td></tr><tr><td>max</td><td>35.0</td><td>23.5</td></tr></tbody></table></div>
# Output can only be rendered in Databricks

# %%
# Create a VectorAssembler object to assemble the mpgusage into one vector column 
from pyspark.ml.feature import VectorAssembler

vecAssembler = VectorAssembler(inputCols=["acceleration"], outputCol="mpgUsage")

vecTraindf = vecAssembler.transform(traindf)

vecTraindf.select("acceleration","mpgUsage","mpg").show(10)
# Out:
# +------------+--------+----+
# |acceleration|mpgUsage| mpg|
from pyspark.ml.regression import LinearRegression

lr = LinearRegression(featuresCol="mpgUsage", labelCol="mpg")
lrModel = lr.fit(vecTraindf)

# %%
#Leverage Pipeline class from ML package
from pyspark.ml import Pipeline

pipeline = Pipeline(stages=[vecAssembler, lr])
pipelineModel = pipeline.fit(traindf)

# %%
#now applying to my test set
preddf = pipelineModel.transform(testdf)

preddf.select("acceleration","mpgUsage","mpg", "prediction").show(20)
# Out:
# +------------+--------+----+----------+
# |acceleration|mpgUsage| mpg|prediction|
# +------------+--------+----+----------+
# |        18.5|   [9.0]| 9.0|       9.0|
# |        14.0|  [11.0]|11.0|      11.0|
# |        12.0|  [13.0]|13.0|      13.0|
# |        12.5|  [13.0]|13.0|      13.0|
# |        14.5|  [14.0]|14.0|      14.0|
# |        12.0|  [14.0]|14.0|      14.0|
# |        13.5|  [14.0]|14.0|      14.0|
# |        12.0|  [14.0]|14.0|      14.0|
# |        11.5|  [14.0]|14.0|      14.0|
# |        21.0|  [15.0]|15.0|      15.0|
# |        12.5|  [15.0]|15.0|      15.0|
# |        13.5|  [15.0]|15.0|      15.0|
# |        14.0|  [16.0]|16.0|      16.0|
# |        13.0|  [16.0]|16.0|      16.0|
# |        11.5|  [17.0]|17.0|      17.0|
# |        14.5|  [18.0]|18.0|      18.0|
# |        19.0|  [18.0]|18.0|      18.0|
# |        14.5|  [18.0]|18.0|      18.0|
# |        13.5|  [19.0]|19.0|      19.0|
# |        16.0|  [20.0]|20.0|      20.0|
# +------------+--------+----+----------+
# only showing top 20 rows

# %%
display(preddf)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mpg</th><th>cylinders</th><th>displacement</th><th>horsepower</th><th>weight</th><th>acceleration</th><th>model</th><th>origin</th><th>mpgUsage</th><th>prediction</th></tr></thead><tbody><tr><td>9.0</td><td>8</td><td>304</td><td>193</td><td>4732</td><td>18.5</td><td>70</td><td>1</td><td>Map(vectorType -> dense, length -> 1, values -> List(9.0))</td><td>9.0</td></tr><tr><td>11.0</td><td>8</td><td>400</td><td>150</td><td>4997</td><td>14.0</td><td>73</td><td>1</td><td>Map(vectorType -> dense, length -> 1, values -> List(11.0))</td><td>11.0</td></tr><tr><td>13.0</td><td>8</td><td>400</td><td>170</td><td>4746</td><td>12.0</td><td>71</td><td>1</td><td>Map(vectorType -> dense, length -> 1, values -> List(13.0))</td><td>13.0</td></tr><tr><td>13.0</td><td>8</td><td>400</td><td>190</td><td>4422</td><td>12.5</td><td>72</td><td>1</td><td>Map(vectorType -> dense, length -> 1, values -> List(13.0))</td><td>13.0</td></tr><tr><td>14.0</td><td>8</td><td>302</td><td>137</td><td>4042</td><td>14.5</td><td>73</td><td>1</td><td>Map(vectorType -> dense, length -> 1, values -> List(14.0))</td><td>14.0</td></tr><tr><td>14.0</td><td>8</td><td>350</td><td>165</td><td>4209</td><td>12.0</td><td>71</td><td>1</td><td>Map(vectorType -> dense, length -> 1, values -> List(14.0))</td><td>14.0</td></tr><tr><td>14.0</td><td>8</td><td>351</td><td>148</td><td>4657</td><td>13.5</td><td>75</td><td>1</td><td>Map(vectorType -> dense, length -> 1, values -> List(14.0))</td><td>14.0</td></tr><tr><td>14.0</td><td>8</td><td>400</td><td>175</td><td>4385</td><td>12.0</td><td>72</td><td>1</td><td>Map(vectorType -> dense, length -> 1, values -> List(14.0))</td><td>14.0</td></tr><tr><td>14.0</td><td>8</td><td>400</td><td>175</td><td>4464</td><td>11.5</td><td>71</td><td>1</td><td>Map(vectorType -> dense, length -> 1, values -> List(14.0))</td><td>14.0</td></tr><tr><td>15.0</td><td>6</td><td>250</td><td>72</td><td>3432</td><td>21.0</td><td>75</td><td>1</td><td>Map(vectorType -> dense, length -> 1, values -> List(15.0))</td><td>15.0</td></tr><tr><td>15.0</td><td>8</td><td>304</td><td>150</td><td>3892</td><td>12.5</td><td>72</td><td>1</td><td>Map(vectorType -> dense, length -> 1, values -> List(15.0))</td><td>15.0</td></tr><tr><td>15.0</td><td>8</td><td>318</td><td>150</td><td>4135</td><td>13.5</td><td>72</td><td>1</td><td>Map(vectorType -> dense, length -> 1, values -> List(15.0))</td><td>15.0</td></tr><tr><td>16.0</td><td>8</td><td>302</td><td>140</td><td>4141</td><td>14.0</td><td>74</td><td>1</td><td>Map(vectorType -> dense, length -> 1, values -> List(16.0))</td><td>16.0</td></tr><tr><td>16.0</td><td>8</td><td>318</td><td>150</td><td>4190</td><td>13.0</td><td>76</td><td>1</td><td>Map(vectorType -> dense, length -> 1, values -> List(16.0))</td><td>16.0</td></tr><tr><td>17.0</td><td>8</td><td>304</td><td>150</td><td>3672</td><td>11.5</td><td>72</td><td>1</td><td>Map(vectorType -> dense, length -> 1, values -> List(17.0))</td><td>17.0</td></tr><tr><td>18.0</td><td>6</td><td>171</td><td>97</td><td>2984</td><td>14.5</td><td>75</td><td>1</td><td>Map(vectorType -> dense, length -> 1, values -> List(18.0))</td><td>18.0</td></tr><tr><td>18.0</td><td>6</td><td>225</td><td>95</td><td>3785</td><td>19.0</td><td>75</td><td>1</td><td>Map(vectorType -> dense, length -> 1, values -> List(18.0))</td><td>18.0</td></tr><tr><td>18.0</td><td>6</td><td>250</td><td>88</td><td>3139</td><td>14.5</td><td>71</td><td>1</td><td>Map(vectorType -> dense, length -> 1, values -> List(18.0))</td><td>18.0</td></tr><tr><td>19.0</td><td>3</td><td>70</td><td>97</td><td>2330</td><td>13.5</td><td>72</td><td>3</td><td>Map(vectorType -> dense, length -> 1, values -> List(19.0))</td><td>19.0</td></tr><tr><td>20.0</td><td>6</td><td>232</td><td>100</td><td>2914</td><td>16.0</td><td>75</td><td>1</td><td>Map(vectorType -> dense, length -> 1, values -> List(20.0))</td><td>20.0</td></tr><tr><td>20.0</td><td>8< ...
# Output can only be rendered in Databricks
# Output can only be rendered in Databricks

# %%
#let us try to predict the mpg usage with the weight of the car
display(df.select("mpg", "weight").summary())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>summary</th><th>mpg</th><th>weight</th></tr></thead><tbody><tr><td>count</td><td>198</td><td>198</td></tr><tr><td>mean</td><td>19.71969696969697</td><td>3177.8888888888887</td></tr><tr><td>stddev</td><td>5.814253963002064</td><td>934.7837328417526</td></tr><tr><td>min</td><td>9.0</td><td>1613</td></tr><tr><td>25%</td><td>15.0</td><td>2300</td></tr><tr><td>50%</td><td>19.0</td><td>3021</td></tr><tr><td>75%</td><td>24.5</td><td>4082</td></tr><tr><td>max</td><td>35.0</td><td>5140</td></tr></tbody></table></div>

# %%
# Create a VectorAssembler object to assemble the features into one vector column 
from pyspark.ml.feature import VectorAssembler

vecAssembler = VectorAssembler(inputCols=["weight"], outputCol="mpgUsage/Weight")

vecTraindf = vecAssembler.transform(traindf)

vecTraindf.select("weight","mpg","mpgUsage/Weight").show(5)
# Out:
# +------+----+---------------+
# |weight| mpg|mpgUsage/Weight|
# +------+----+---------------+
# |  4376|10.0|       [4376.0]|
# |  4615|10.0|       [4615.0]|
# |  4382|11.0|       [4382.0]|
# |  3664|11.0|       [3664.0]|
# |  4633|11.0|       [4633.0]|
# +------+----+---------------+
# only showing top 5 rows

# %%
#linear regression 
from pyspark.ml.regression import LinearRegression

lr = LinearRegression(featuresCol="mpgUsage/Weight", labelCol="mpg")
lrModel = lr.fit(vecTraindf)

# %%
#Leverage Pipeline class from ML package
from pyspark.ml import Pipeline

pipeline = Pipeline(stages=[vecAssembler, lr])
pipelineModel = pipeline.fit(traindf)

# %%
#now applying to my test set
preddf = pipelineModel.transform(testdf)

preddf.select("weight","mpgUsage/Weight", "mpg","prediction").show(10)
# Out:
# +------+---------------+----+------------------+
# |weight|mpgUsage/Weight| mpg|        prediction|
# +------+---------------+----+------------------+
# |  4732|       [4732.0]| 9.0|10.800139650289928|
# |  4997|       [4997.0]|11.0| 9.304862765427291|
# |  4746|       [4746.0]|13.0|10.721143890334918|
# |  4422|       [4422.0]|13.0|12.549331477865088|
# |  4042|       [4042.0]|14.0|14.693502105215284|
# |  4209|       [4209.0]|14.0|13.751195540037699|
# |  4657|       [4657.0]|14.0|11.223331221477466|
# |  4385|       [4385.0]|14.0|12.758105986317606|
# |  4464|       [4464.0]|14.0|12.312344198000066|
# |  3432|       [3432.0]|15.0|  18.1354602175406|
# +------+---------------+----+------------------+
